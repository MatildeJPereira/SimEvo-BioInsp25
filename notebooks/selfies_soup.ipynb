# %%
# The initial digital soup of molecules that were though to be present in the prebiotic times
# Hydrogen cyanide, Formaldehyde, Methanol, Ethanol, Acetaldehyde, Glycolaldehyde, Formic acid, Urea, Ammonia, Water, Glycine, Alanine, Acetic acid, Ethylamine, Methanethiol, Pyruvic acid, Acetone, Carbon dioxide, Carbonyl sulfide, Phosphoric acid  
soup = ['[C][#N]', '[C][=O]', '[C][O]', '[C][C][O]', '[C][C][=O]', '[O][=C][C][O]', '[O][=C][O]', '[N][C][=Branch1][C][=O][N]', '[N]', '[O]', '[N][C][C][=Branch1][C][=O][O]', '[C][C][Branch1][=Branch1][C][=Branch1][C][=O][O][N]', '[C][C][=Branch1][C][=O][O]', '[C][C][N]', '[C][S]', '[C][C][=Branch1][C][=O][C][=Branch1][C][=O][O]', '[C][C][=Branch1][C][=O][C]', '[O][=C][=O]', '[O][=C][=S]', '[O][P][=Branch1][C][=O][Branch1][C][O][O]']
# Out:
# Running cells with 'base (Python 3.13.5)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n base ipykernel --update-deps --force-reinstall'
