# %%
# The initial digital soup of molecules that were though to be present in the prebiotic times
# Contents:
# Hydrogen cyanide, Formaldehyde, Methanol, Ethanol, Acetaldehyde, Glycolaldehyde, Formic acid, 
# Urea, Ammonia, Water, Glycine, Alanine, Acetic acid, Ethylamine, Methanethiol, Pyruvic acid, 
# Acetone, Carbon dioxide, Carbonyl sulfide, Phosphoric acid, Benzene, Imidazole, Pyrrole, 
# Cyclopentane, Cyclohexane, Aminopyrimidine, Furan, Lactic acid, Purine, Pyrophosphate, 
# beta-Hydroxybutyric acid, Glyceraldehyde, Dihydroxyacetone, Formamide, Ethene, 
# Propionic acid, Succinic acid, Cysteamine, Thiourea, Ribose
soup = ['[C][#N]', '[C][=O]', '[C][O]', '[C][C][O]', '[C][C][=O]', '[O][=C][C][O]', 
        '[O][=C][O]', '[N][C][=Branch1][C][=O][N]', '[N]', '[O]', 
        '[N][C][C][=Branch1][C][=O][O]', '[C][C][Branch1][=Branch1][C][=Branch1][C][=O][O][N]', 
        '[C][C][=Branch1][C][=O][O]', '[C][C][N]', '[C][S]', '[C][C][=Branch1][C][=O][C][=Branch1][C][=O][O]', 
        '[C][C][=Branch1][C][=O][C]', '[O][=C][=O]', '[O][=C][=S]', '[O][P][=Branch1][C][=O][Branch1][C][O][O]', 
        '[C][=C][C][=C][C][=C][Ring1][=Branch1]', '[C][=C][N][=C][NH1][Ring1][Branch1]', '[C][C][=C][NH1][C][=Ring1][Branch1]', 
        '[C][C][C][C][C][Ring1][Branch1]', '[C][C][C][C][C][C][Ring1][=Branch1]', '[N][C][=N][C][=C][N][Ring1][Branch1]', 
        '[C][C][=C][O][C][=Ring1][Branch1]', '[O][C][C][=Branch1][C][=O][O]', 
        '[C][=N][C][=N][C][NH1][C][=N][C][Ring1][=Branch2][=Ring1][Branch1]', 
        '[O][P][=Branch1][C][=O][Branch1][C][O][O][P][=Branch1][C][=O][Branch1][C][O][O]', 
        '[C][C][Branch1][C][O][C][=Branch1][C][=O][O]', '[O][=C][C][Branch1][C][O][C][O]', 
        '[O][=C][Branch1][Ring1][C][O][C][O]', '[N][C][=O]', '[C][=C]', '[C][C][C][=Branch1][C][=O][O]', 
        '[O][=C][Branch1][C][O][C][C][C][=Branch1][C][=O][O]', '[N][C][C][S]', '[N][C][=Branch1][C][=S][N]', 
        '[O][C][C@H1][O][C][Branch1][C][O][C@H1][Branch1][C][O][C@@H1][Ring1][#Branch1][O]']
# Out:
# 40
